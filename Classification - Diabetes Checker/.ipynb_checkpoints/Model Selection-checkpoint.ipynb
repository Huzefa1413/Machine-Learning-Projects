# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,roc_auc_score,roc_curve

from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import BaggingClassifier
# Out:
# C:\Users\huzef\AppData\Roaming\Python\Python39\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\huzef\AppData\Roaming\Python\Python39\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\huzef\AppData\Roaming\Python\Python39\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # Splitting Data into Training Set and Testing Set

# %%
dataset = pd.read_csv("diabetes.csv")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
dataset
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# ...

# %% [markdown]
# ## Applying KNN

# %%
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
knn_pred = knn.predict(X_test)
accuracy_knn = accuracy_score(y_test, knn_pred)
precision_knn = precision_score(y_test, knn_pred)
recall_knn = recall_score(y_test, knn_pred)
f1_knn= f1_score(y_test, knn_pred)
knn_confusion = confusion_matrix(y_test, knn_pred)
knn_auc_score = roc_auc_score(y_test, knn_pred)

print("KNN Accuracy:", "{:.3f}".format(accuracy_knn))
print("KNN Precision:", "{:.3f}".format(precision_knn))
print("KNN Recall:", "{:.3f}".format(recall_knn))
print("KNN F1 score:", "{:.3f}".format(f1_knn))
print("KNN AUC Score:", knn_auc_score)

plt.figure(figsize=(5, 4))
sns.heatmap(knn_confusion, annot=True, cmap='Blues', fmt='g', xticklabels=['Predicted No Diabeties', 'Predicted Diabeties'], yticklabels=['Actual No Diabeties', 'Actual Diabeties'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

fpr, tpr, thresholds = roc_curve(y_test, knn_pred)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(knn_auc_score))
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# Out:
# KNN Accuracy: 0.755
# KNN Precision: 0.632
# KNN Recall: 0.581
# KNN F1 score: 0.605
# KNN AUC Score: 0.7095533498759304

# %% [markdown]
# ## Applying Naive Bayes

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)
nb_pred = nb.predict(X_test)
accuracy_nb = accuracy_score(y_test, nb_pred)
precision_nb = precision_score(y_test, nb_pred)
recall_nb = recall_score(y_test, nb_pred)
f1_nb= f1_score(y_test, nb_pred)
nb_confusion = confusion_matrix(y_test, nb_pred)
nb_auc_score = roc_auc_score(y_test, nb_pred)

print("Naive Bayes Accuracy:", "{:.3f}".format(accuracy_nb))
print("Naive Bayes Precision:", "{:.3f}".format(precision_nb))
print("Naive Bayes Recall:", "{:.3f}".format(recall_nb))
print("Naive Bayes F1 score:", "{:.3f}".format(f1_nb))
print("Naive Bayes AUC Score:", nb_auc_score)

plt.figure(figsize=(5, 4))
sns.heatmap(nb_confusion, annot=True, cmap='Blues', fmt='g', xticklabels=['Predicted No Diabeties', 'Predicted Diabeties'], yticklabels=['Actual No Diabeties', 'Actual Diabeties'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

fpr, tpr, thresholds = roc_curve(y_test, nb_pred)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(nb_auc_score))
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# Out:
# Naive Bayes Accuracy: 0.766
# Naive Bayes Precision: 0.673
# Naive Bayes Recall: 0.532
# Naive Bayes F1 score: 0.595
# Naive Bayes AUC Score: 0.704590570719603

# %% [markdown]
# # Applying Decision Tree

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
dt_pred = dt.predict(X_test)
accuracy_dt = accuracy_score(y_test, dt_pred)
precision_dt = precision_score(y_test, dt_pred)
recall_dt = recall_score(y_test, dt_pred)
f1_dt= f1_score(y_test, dt_pred)
dt_confusion = confusion_matrix(y_test, dt_pred)
dt_auc_score = roc_auc_score(y_test, dt_pred)

print("Decision Tree Accuracy:", "{:.3f}".format(accuracy_dt))
print("Decision Tree Precision:", "{:.3f}".format(precision_dt))
print("Decision Tree Recall:", "{:.3f}".format(recall_dt))
print("Decision Tree F1 score:", "{:.3f}".format(f1_dt))
print("Decision Tree AUC Score:", dt_auc_score)

plt.figure(figsize=(5, 4))
sns.heatmap(dt_confusion, annot=True, cmap='Blues', fmt='g', xticklabels=['Predicted No Diabeties', 'Predicted Diabeties'], yticklabels=['Actual No Diabeties', 'Actual Diabeties'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

fpr, tpr, thresholds = roc_curve(y_test, dt_pred)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(dt_auc_score))
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# Out:
# Decision Tree Accuracy: 0.740
# Decision Tree Precision: 0.591
# Decision Tree Recall: 0.629
# Decision Tree F1 score: 0.609
# Decision Tree AUC Score: 0.7106699751861041

# %% [markdown]
# # Applying Random Forest

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
rf_pred = rf.predict(X_test)
accuracy_rf = accuracy_score(y_test, rf_pred)
precision_rf = precision_score(y_test, rf_pred)
recall_rf = recall_score(y_test, rf_pred)
f1_rf= f1_score(y_test, rf_pred)
rf_confusion = confusion_matrix(y_test, rf_pred)
rf_auc_score = roc_auc_score(y_test, rf_pred)

print("Random Forest Accuracy:", "{:.3f}".format(accuracy_rf))
print("Random Forest Precision:", "{:.3f}".format(precision_rf))
print("Random Forest Recall:", "{:.3f}".format(recall_rf))
print("Random Forest F1 score:", "{:.3f}".format(f1_rf))
print("Random Forest AUC Score:", rf_auc_score)

plt.figure(figsize=(5, 4))
sns.heatmap(rf_confusion, annot=True, cmap='Blues', fmt='g', xticklabels=['Predicted No Diabeties', 'Predicted Diabeties'], yticklabels=['Actual No Diabeties', 'Actual Diabeties'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

fpr, tpr, thresholds = roc_curve(y_test, rf_pred)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(rf_auc_score))
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# Out:
# Random Forest Accuracy: 0.792
# Random Forest Precision: 0.712
# Random Forest Recall: 0.597
# Random Forest F1 score: 0.649
# Random Forest AUC Score: 0.7406947890818858

# %% [markdown]
# # Applying Logistic Regression

# %%
lr = RandomForestClassifier()
lr.fit(X_train,y_train)
lr_pred = lr.predict(X_test)
accuracy_lr = accuracy_score(y_test, lr_pred)
precision_lr = precision_score(y_test, lr_pred)
recall_lr = recall_score(y_test, lr_pred)
f1_lr= f1_score(y_test, lr_pred)
lr_confusion = confusion_matrix(y_test, lr_pred)
lr_auc_score = roc_auc_score(y_test, lr_pred)

print("Logistic Regression Accuracy:", "{:.3f}".format(accuracy_lr))
print("Logistic Regression Precision:", "{:.3f}".format(precision_lr))
print("Logistic Regression Recall:", "{:.3f}".format(recall_lr))
print("Logistic Regression F1 score:", "{:.3f}".format(f1_lr))
print("Logistic Regression AUC Score:", lr_auc_score)

plt.figure(figsize=(5, 4))
sns.heatmap(lr_confusion, annot=True, cmap='Blues', fmt='g', xticklabels=['Predicted No Diabeties', 'Predicted Diabeties'], yticklabels=['Actual No Diabeties', 'Actual Diabeties'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

fpr, tpr, thresholds = roc_curve(y_test, lr_pred)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(lr_auc_score))
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# Out:
# Logistic Regression Accuracy: 0.781
# Logistic Regression Precision: 0.692
# Logistic Regression Recall: 0.581
# Logistic Regression F1 score: 0.632
# Logistic Regression AUC Score: 0.7287841191066997

# %% [markdown]
# # Applying Bagging using Decision Tree

# %%
bg = BaggingClassifier(estimator=dt, n_estimators=10)
bg.fit(X_train,y_train)
bg_pred = bg.predict(X_test)
accuracy_bg = accuracy_score(y_test, bg_pred)
precision_bg = precision_score(y_test, bg_pred)
recall_bg = recall_score(y_test, bg_pred)
f1_bg= f1_score(y_test, bg_pred)
bg_confusion = confusion_matrix(y_test, bg_pred)
bg_auc_score = roc_auc_score(y_test, bg_pred)

print("Bagging Accuracy:", "{:.3f}".format(accuracy_bg))
print("Bagging Precision:", "{:.3f}".format(precision_bg))
print("Bagging Recall:", "{:.3f}".format(recall_bg))
print("Bagging F1 score:", "{:.3f}".format(f1_bg))
print("Bagging AUC Score:", bg_auc_score)

plt.figure(figsize=(5, 4))
sns.heatmap(bg_confusion, annot=True, cmap='Blues', fmt='g', xticklabels=['Predicted No Diabeties', 'Predicted Diabeties'], yticklabels=['Actual No Diabeties', 'Actual Diabeties'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

fpr, tpr, thresholds = roc_curve(y_test, bg_pred)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(bg_auc_score))
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# Out:
# Bagging Accuracy: 0.781
# Bagging Precision: 0.708
# Bagging Recall: 0.548
# Bagging F1 score: 0.618
# Bagging AUC Score: 0.7203473945409429

# %% [markdown]
# # Evaluating the performance of all models

# %%
models = ['KNN', 'Naive Bayes', 'Decision Tree', 'Random Forest', 'Logistic Regression', 'Bagging']

accuracies = [accuracy_knn, accuracy_nb, accuracy_dt, accuracy_rf, accuracy_lr, accuracy_bg]
precisions = [precision_knn, precision_nb, precision_dt, precision_rf, precision_lr, precision_bg]
recalls = [recall_knn, recall_nb, recall_dt, recall_rf, recall_lr, recall_bg]
f1_scores = [f1_knn, f1_nb, f1_dt, f1_rf, f1_lr, f1_bg]
auc_scores = [knn_auc_score, nb_auc_score, dt_auc_score, rf_auc_score, lr_auc_score, bg_auc_score]

metrics_data = {'Accuracy': accuracies, 'Precision': precisions, 'Recall': recalls, 'F1 Score': f1_scores, 'AUC Score': auc_scores}

# Plotting
fig, axs = plt.subplots(3, 2, figsize=(10, 12))

for i, (metric, data) in enumerate(metrics_data.items()):
    row = i // 2
    col = i % 2
    ax = axs[row, col]
    ax.bar(models, data, color='blue')
    ax.set_title(f'{metric} of Different Models')
    ax.set_ylabel(metric)
    ax.set_ylim(0, 1)
    ax.tick_params(axis='x', rotation=45)
    for idx, val in enumerate(data):
        ax.text(idx, val + 0.01, f'{val:.2f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()
